# %%
import os
os.chdir(os.path.abspath(os.path.join(os.getcwd(), '..', '..')))
print(os.getcwd())
import matplotlib.pyplot as plt

from astropy import units as u
import sunpy.data.sample
import sunpy.map

from Data.utils import transfer_date_to_id, get_modal_dir
# import sunkit_image.enhance as enhance
# Out:
# /mnt/nas/home/huxing/202407/ctf/SolarCLIP_tq

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0094.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')

plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0131.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')

plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0171.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')

plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0193.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')

plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0211.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')

plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0304.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_0335.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0000_1600.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0004_1700.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax, clip_interval=(1, 99.99) * u.percent)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/AIA20100601_0029_4500.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot(axes=ax)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/hmi.M_720s.20100601_000000_TAI.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot_settings['cmap'] = 'hmimag'
fits.plot_settings['norm'] = plt.Normalize(-1500, 1500)
fits.plot(axes=ax)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/hmi.M_720s.20100601_120000_TAI.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot_settings['cmap'] = 'hmimag'
fits.plot_settings['norm'] = plt.Normalize(-1500, 1500)
fits.plot(axes=ax)

plt.axis('off')
plt.show()

# %%
fits = 'Plot/magnet_spectral_images/fits/hmi.M_720s.20100612_000000_TAI.fits'
fits = sunpy.map.Map(fits)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(121, projection=fits)
fits.plot_settings['cmap'] = 'hmimag'
fits.plot_settings['norm'] = plt.Normalize(-1500, 1500)
fits.plot(axes=ax)

plt.axis('off')
plt.show()
