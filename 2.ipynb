# %%
import torch

# %%
path = 'checkpoints/recon/0816_test1/SolarCLIP/epoch_200.pt'
state_dict = torch.load(path)['model']
list(state_dict.keys())
# Out:
# ['logit_scale',
#  'visual_mag.class_embedding',
#  'visual_mag.positional_embedding',
#  'visual_mag.proj',
#  'visual_mag.conv1.conv1.weight',
#  'visual_mag.conv1.ln_pre.norm.weight',
#  'visual_mag.conv1.ln_pre.norm.bias',
#  'visual_mag.conv1.ln_pre.norm.running_mean',
#  'visual_mag.conv1.ln_pre.norm.running_var',
#  'visual_mag.conv1.ln_pre.norm.num_batches_tracked',
#  'visual_mag.ln_pre.norm.weight',
#  'visual_mag.ln_pre.norm.bias',
#  'visual_mag.ln_pre.norm.running_mean',
#  'visual_mag.ln_pre.norm.running_var',
#  'visual_mag.ln_pre.norm.num_batches_tracked',
#  'visual_mag.transformer.resblocks.0.attn.in_proj_weight',
#  'visual_mag.transformer.resblocks.0.attn.in_proj_bias',
#  'visual_mag.transformer.resblocks.0.attn.out_proj.weight',
#  'visual_mag.transformer.resblocks.0.attn.out_proj.bias',
#  'visual_mag.transformer.resblocks.0.ln_1.norm.weight',
#  'visual_mag.transformer.resblocks.0.ln_1.norm.bias',
# ...
